# %%
# %pip install pandas numpy requests beautifulsoup4

# %%
import pandas as pd
import requests
from urllib import response
from bs4 import BeautifulSoup

# %%
df =pd.read_csv('data/listing_address.csv')
df.head()
# Out:
#    Sale Date                Address             City    Zip
# 0  11/12/2025  2811 VILLAGE BLVD 404  WEST PALM BEACH  33409
# 1  11/12/2025          915 SW 3RD ST    BOYNTON BEACH  33435
# 2  11/12/2025      5619 KINGSMILL CT       LAKE WORTH  33463
# 3  11/12/2025      22171 SW 62ND AVE       BOCA RATON  33428
# 4  11/12/2025           1026 10TH LN       GREENACRES  33463

# %%
#cleaning column names (removing leading/trailing spaces)
df.columns = df.columns.str.strip()

# %%
# creating full address column (not including zip code as for some properties there is a range of zip codes)
df["full_address"] = (df["Address"].str.strip()+ ", " + df["City"].str.strip() + " " + df["Zip"].astype(str))
#df["full_address"] = (df["Address"].str.strip()+ ", " + df["City"].str.strip())
df["full_address"].head()
# Out:
# 0    2811 VILLAGE BLVD 404, WEST PALM BEACH 33409
# 1              915 SW 3RD ST, BOYNTON BEACH 33435
# 2             5619 KINGSMILL CT, LAKE WORTH 33463
# 3             22171 SW 62ND AVE, BOCA RATON 33428
# 4                  1026 10TH LN, GREENACRES 33463
# Name: full_address, dtype: object

# %%
#helper function to check for empty addresses

def is_empty_address(address):
    if address is None:
        return True
    if isinstance(address, float):  # NaN case
        return True
    if address.strip() == "":
        return True
    return False

# %%
#api call payload builder needs address to look for in the searchText field

def build_payload(search_address):
    return {
        "inputName": "addresssearch",
        "searchLimit": "20",
        "uID": "89540f28-8b9a-4aed-b609-72529f86a3ca",
        "version": 2,
        "removeZip": True,
        "papaVersion": True,
        "removeChar": "_",
        "removeSpace": True,
        "papaVariance": False,
        "searchText": search_address
        }

# %%
#calling api and returning json response
def api_call(address):
    url = "https://maps.pbc.gov/giswebapi/anysearch"
    response = requests.post(url, json=build_payload(address))
    if response.status_code == 200:
        data = response.json()
        return data
    else:
        print(f"Error: {response.status_code}")
        return None

# %%
#helper function to normalize text : convert everything in to upercase and remove extra spaces and adds only 1 space between words
def normalize(text):
    return " ".join(text.upper().split())

# %%
#finds the pcn number from the api response data for the given address
def get_pcn_number(address, data):
    address_norm = normalize(address)
    for item in data:
         search_term = item.get("searchTerm", "")
         if normalize(search_term) == address_norm:
            print("get_pcn_number :" + str(item.get("PCN")))
            return item.get("PCN")

    return None

# %%
# calling api and getting pcn number for the given address
def get_pcn(address):
    if is_empty_address(address):
        return None
    
    data = api_call(address)
    if not data:
        return None

    return get_pcn_number(address, data)

# %%
#saving all the pcn results in a list
pcn_results = []
for idx, row in df.iterrows():
    address = row["full_address"]
    print(f"Processing row {idx}: {address}")
    pcn = get_pcn(address)
    pcn_results.append(pcn)

# %%
#creating a new column in dataframe to save pcn results
df["PCN"] = pcn_results
df["PCN"].head()
# Out:
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# Name: PCN, dtype: object

# %%
# function to get property details using pcn number
def get_property_details(pcn):
    if pcn is None or str(pcn).strip() == "":
        return None
    
    url = "https://pbcpao.gov/Property/MapDetails"
    params ={"parcelId": pcn}
    
    response = requests.get(url, params=params)
    if response.status_code == 200:
        return response.text
    else:
        print(f"Error fetching details for PCN {pcn}: {response.status_code}")
        return None

# %%
#getting owners from the property details page
def get_owners(soup):
    owners_section = soup.find("div", class_="map-owners")
    if not owners_section:
        return None

    owners = [
        td.get_text(" ", strip=True)
        for td in owners_section.find_all("td")
        if td.get_text(strip=True)
    ]

    return "; ".join(owners) if owners else None

# %%
#getting mailing address from the property details page
def get_mailing_address(soup):
    for row in soup.find_all("tr"):
        label_cell = row.find("td", class_="label")
        if not label_cell:
            continue

        if label_cell.get_text(strip=True) == "Mailing Address":
            value_cell = row.find("td", class_="value")
            if not value_cell:
                return None

            lines = [
                label.get_text(strip=True)
                for label in value_cell.find_all("label")
                if label.get_text(strip=True)
            ]

            return ", ".join(lines) if lines else None

    return None

# %%
def get_location(soup):
    for row in soup.find_all("tr"):
        label_cell = row.find("td", class_="label")
        if not label_cell:
            continue

        if label_cell.get_text(strip=True) == "Location":
            value_cell = row.find("td", class_="value")
            if not value_cell:
                return None

            location_label = value_cell.find("label", id="lblLocation")
            if not location_label:
                return None

            return location_label.get_text(strip=True)

    return None

# %%
#saving the parsed property details in a dictionary
def parse_property_html(html):
    soup = BeautifulSoup(html, "html.parser")

    return {
        "Owner_Name": get_owners(soup),
        "Mailing_Address": get_mailing_address(soup),
        "Location": get_location(soup)
    }

# %%
#creating new columns for Owner_Name and Mailing_Address
df["Owner_Name"] = None
df["Mailing_Address"] = None
df["Location"] = None


for idx, pcn in df["PCN"].items():
    if pd.isna(pcn) or not str(pcn).strip():
        print(f"Skipping row {idx} due to missing PCN")
        continue

    try:
        html = get_property_details(pcn)
        if not html:
            print(f"No HTML returned for PCN {pcn}")
            continue

        parsed = parse_property_html(html)

        df.at[idx, "Owner_Name"] = parsed.get("Owner_Name")
        df.at[idx, "Mailing_Address"] = parsed.get("Mailing_Address")
        df.at[idx, "Location"] = parsed.get("Location")

        print(f"Processed PCN {pcn}")

    except Exception as e:
        print(f"Failed PCN {pcn}: {e}")
# Out:
# Skipping row 0 due to missing PCN
# Skipping row 1 due to missing PCN
# Skipping row 2 due to missing PCN
# Skipping row 3 due to missing PCN
# Skipping row 4 due to missing PCN
# Skipping row 5 due to missing PCN
# Skipping row 6 due to missing PCN
# Skipping row 7 due to missing PCN
# Skipping row 8 due to missing PCN
# Skipping row 9 due to missing PCN
# Skipping row 10 due to missing PCN
# Skipping row 11 due to missing PCN
# Skipping row 12 due to missing PCN
# Skipping row 13 due to missing PCN
# Skipping row 14 due to missing PCN
# Skipping row 15 due to missing PCN
# Skipping row 16 due to missing PCN
# Skipping row 17 due to missing PCN
# Skipping row 18 due to missing PCN
# Skipping row 19 due to missing PCN
# Skipping row 20 due to missing PCN
# Skipping row 21 due to missing PCN
# Skipping row 22 due to missing PCN
# Skipping row 23 due to missing PCN
# Skipping row 24 due to missing PCN
# Skipping row 25 due to missing PCN
# Skipping row 26 due to missing PCN
# Skipping row 27 due to missing PCN
# Skipping row 28 due to missing PCN
# Skipping row 29 due to missing PCN
# Skipping row 30 due to missing PCN
# Skipping row 31 due to missing PCN
# Skipping row 32 due to missing PCN
# Skipping row 33 due to missing PCN
# Skipping row 34 due to missing PCN
# Skipping row 35 due to missing PCN
# Skipping row 36 due to missing PCN
# Skipping row 37 due to missing PCN
# Skipping row 38 due to missing PCN
# Skipping row 39 due to missing PCN
# Skipping row 40 due to missing PCN
# Skipping row 41 due to missing PCN
# Skipping row 42 due to missing PCN
# Skipping row 43 due to missing PCN
# Skipping row 44 due to missing PCN
# Skipping row 45 due to missing PCN
# Skipping row 46 due to missing PCN
# Skipping row 47 due to missing PCN
# Skipping row 48 due to missing PCN
# Skipping row 49 due to missing PCN
# Skipping row 50 due to missing PCN
# Skipping row 51 due to missing PCN
# Skipping row 52 due to missing PCN
# Skipping row 53 due to missing PCN
# Skipping row 54 due to missing PCN
# Skipping row 55 due to missing PCN
# Skipping row 56 due to missing PCN
# Skipping row 57 due to missing PCN
# Skipping row 58 due to missing PCN
# Skipping row 59 due to missing PCN
# Skipping row 60 due to missing PCN
# Skipping row 61 due to missing PCN
# Skipping row 62 due to missing PCN
# Skipping row 63 due to missing PCN
# Skipping row 64 due to missing PCN
# Skipping row 65 due to missing PCN
# Skipping row 66 due to missing PCN
# Skipping row 67 due to missing PCN
# Skipping row 68 due to missing PCN
# Skipping row 69 due to missing PCN
# Skipping row 70 due to missing PCN
# Skipping row 71 due to missing PCN
# Skipping row 72 due to missing PCN
# Skipping row 73 due to missing PCN
# Skipping row 74 due to missing PCN
# Skipping row 75 due to missing PCN
# Skipping row 76 due to missing PCN
# Skipping row 77 due to missing PCN
# Skipping row 78 due to missing PCN
# Skipping row 79 due to missing PCN
# Skipping row 80 due to missing PCN
# Skipping row 81 due to missing PCN
# Skipping row 82 due to missing PCN
# Skipping row 83 due to missing PCN
# Skipping row 84 due to missing PCN
# Skipping row 85 due to missing PCN
# Skipping row 86 due to missing PCN
# Skipping row 87 due to missing PCN
# Skipping row 88 due to missing PCN
# Skipping row 89 due to missing PCN
# Skipping row 90 due to missing PCN
# Skipping row 91 due to missing PCN
# Skipping row 92 due to missing PCN
# Skipping row 93 due to missing PCN
# Skipping row 94 due to missing PCN
# Skipping row 95 due to missing PCN
# Skipping row 96 due to missing PCN
# Skipping row 97 due to missing PCN
# Skipping row 98 due to missing PCN
# Skipping row 99 due to missing PCN
# Skipping row 100 due to missing PCN
# Skipping row 101 due to missing PCN
# Skipping row 102 due to missing PCN
# Skipping row 103 due to missing PCN
# Skipping row 104 due to missing PCN
# Skipping row 105 due to missing PCN
# Skipping row 106 due to missing PCN
# Skipping row 107 due to missing PCN
# Skipping row 108 due to missing PCN
# Skipping row 109 due to missing PCN
# Skipping row 110 due to missing PCN
# Skipping row 111 due to missing PCN
# Skipping row 112 due to missing PCN
# Skipping row 113 due to missing PCN
# Skipping row 114 due to missing PCN
# Skipping row 115 due to missing PCN
# Skipping row 116 due to missing PCN
# Skipping row 117 due to missing PCN
# Skipping row 118 due to missing PCN
# Skipping row 119 due to missing PCN
# Skipping row 120 due to missing PCN
# Skipping row 121 due to missing PCN
# Skipping row 122 due to missing PCN
# Skipping row 123 due to missing PCN
# Skipping row 124 due to missing PCN
# Skipping row 125 due to missing PCN
# Skipping row 126 due to missing PCN
# Skipping row 127 due to missing PCN
# Skipping row 128 due to missing PCN
# Skipping row 129 due to missing PCN
# Skipping row 130 due to missing PCN
# Skipping row 131 due to missing PCN
# Skipping row 132 due to missing PCN
# Skipping row 133 due to missing PCN
# Skipping row 134 due to missing PCN
# Skipping row 135 due to missing PCN
# Skipping row 136 due to missing PCN
# Skipping row 137 due to missing PCN
# Skipping row 138 due to missing PCN
# Skipping row 139 due to missing PCN
# Skipping row 140 due to missing PCN
# Skipping row 141 due to missing PCN
# Skipping row 142 due to missing PCN
# Skipping row 143 due to missing PCN
# Skipping row 144 due to missing PCN
# Skipping row 145 due to missing PCN
# Skipping row 146 due to missing PCN
# Skipping row 147 due to missing PCN
# Skipping row 148 due to missing PCN
# Skipping row 149 due to missing PCN
# Skipping row 150 due to missing PCN
# Skipping row 151 due to missing PCN
# Skipping row 152 due to missing PCN
# Skipping row 153 due to missing PCN
# Skipping row 154 due to missing PCN
# Skipping row 155 due to missing PCN
# Skipping row 156 due to missing PCN
# Skipping row 157 due to missing PCN
# Skipping row 158 due to missing PCN
# Skipping row 159 due to missing PCN
# Skipping row 160 due to missing PCN
# Skipping row 161 due to missing PCN
# Skipping row 162 due to missing PCN
# Skipping row 163 due to missing PCN
# Skipping row 164 due to missing PCN
# Skipping row 165 due to missing PCN
# Skipping row 166 due to missing PCN
# Skipping row 167 due to missing PCN
# Skipping row 168 due to missing PCN
# Skipping row 169 due to missing PCN
# Skipping row 170 due to missing PCN
# Skipping row 171 due to missing PCN
# Skipping row 172 due to missing PCN
# Skipping row 173 due to missing PCN
# Skipping row 174 due to missing PCN
# Skipping row 175 due to missing PCN
# Skipping row 176 due to missing PCN
# Skipping row 177 due to missing PCN
# Skipping row 178 due to missing PCN
# Skipping row 179 due to missing PCN
# Skipping row 180 due to missing PCN
# Skipping row 181 due to missing PCN
# Skipping row 182 due to missing PCN
# Skipping row 183 due to missing PCN
# Skipping row 184 due to missing PCN
# Skipping row 185 due to missing PCN
# Skipping row 186 due to missing PCN
# Skipping row 187 due to missing PCN
# Skipping row 188 due to missing PCN
# Skipping row 189 due to missing PCN
# Skipping row 190 due to missing PCN
# Skipping row 191 due to missing PCN
# Skipping row 192 due to missing PCN

# %%
#saving the final dataframe to a new csv file
df.to_csv("data/listing_address_final.csv", index=False)
