# %% [markdown]
# ##### Reading property address instead of listing address.
# ###### Need clean the address column

# %%
# %pip install pandas numpy requests beautifulsoup4 re

# %%
import pandas as pd
import requests
from urllib import response
from bs4 import BeautifulSoup
import re

# %%
df =pd.read_csv('data/property_address.csv')
df.head()
# Out:
#   First_Name_1 Last_Name_1 First_Name_2 Last_Name_2  companyName  \
# 0          NaN         NaN          NaN         NaN          NaN
# 1          NaN         NaN          NaN         NaN          NaN
# 2          NaN         NaN          NaN         NaN          NaN
# 3          NaN         NaN          NaN         NaN          NaN
# 4          NaN         NaN          NaN         NaN          NaN
#
#   Property_Street_Address  Property_Street_Address_2  Property_City  \
# 0       412 Sw Seventh Ct                        NaN  Boynton Beach
# 1         805 Sw Third St                        NaN  Boynton Beach
# 2        801 Sw Second St                        NaN  Boynton Beach
# 3        720 Sw Second St                        NaN  Boynton Beach
# 4      223 Sw Seventh Ave                        NaN  Boynton Beach
#
#   Property_State  Property_Zip_Code  ... lastSaleInfo.saleDate  \
# 0             FL              33435  ...                   NaN
# 1             FL              33435  ...                   NaN
# 2             FL              33435  ...                   NaN
# 3             FL              33435  ...                   NaN
# 4             FL              33435  ...                   NaN
#
#    lastSaleInfo.ownershipDuration lastSaleInfo.saleAmount mls.status  \
# 0                             NaN                     NaN        NaN
# 1                             NaN                     NaN        NaN
# 2                             NaN                     NaN        NaN
# 3                             NaN                     NaN        NaN
# 4                             NaN                     NaN        NaN
#
#    mls.price  mls.listingType  agentInfo.name  agentInfo.phone  \
# 0        NaN              NaN             NaN              NaN
# 1        NaN              NaN             NaN              NaN
# 2        NaN              NaN             NaN              NaN
# 3        NaN              NaN             NaN              NaN
# 4        NaN              NaN             NaN              NaN
#
#    agentInfo.email  InLead
# 0              NaN      No
# 1              NaN      No
# 2              NaN      No
# 3              NaN      No
# 4              NaN      No
#
# [5 rows x 79 columns]

# %%
#cleaning column names (removing leading/trailing spaces)
df.columns = df.columns.str.strip()

# %%
df["Property_Street_Address"]

# %%
# Function to convert numbers to words (1-100)
def number_to_words(n):
    ones = [
        "", "First", "Second", "Third", "Fourth", "Fifth",
        "Sixth", "Seventh", "Eighth", "Ninth"
    ]

    teens = [
        "Tenth", "Eleventh", "Twelfth", "Thirteenth", "Fourteenth",
        "Fifteenth", "Sixteenth", "Seventeenth", "Eighteenth", "Nineteenth"
    ]

    tens = [
        "", "", "Twenty", "Thirty", "Forty", "Fifty",
        "Sixty", "Seventy", "Eighty", "Ninety"
    ]

    if n < 10:
        return ones[n]

    elif 10 <= n < 20:
        return teens[n - 10]

    elif n < 100:
        ten, one = divmod(n, 10)
        return tens[ten] + ("" if one == 0 else f" {ones[one]}")

    elif n == 100:
        return "One Hundredth"

# %%
def number_to_ordinal(n):
    if 11 <= (n % 100) <= 13:
        suffix = "th"
    else:
        suffix = {1: "st", 2: "nd", 3: "rd"}.get(n % 10, "th")

    return f"{n}{suffix}"

# %%
ordinal_map = {
    number_to_words(i): number_to_ordinal(i)
    for i in range(1, 101)
}

# %%
pattern = re.compile(
    r"\b(" + "|".join(re.escape(k) for k in ordinal_map.keys()) + r")\b",
    re.IGNORECASE
)

# %%
def replace_ordinals(address):
    return pattern.sub(
        lambda m: ordinal_map[m.group(0).title()],
        address
    )

# %%
df["Clean_Address"] = df["Property_Street_Address"].astype(str).str.replace(
    pattern,
    lambda m: ordinal_map[m.group(0).title()],
    regex=True
)

# %%
df["full_address"] = (df["Clean_Address"].str.strip()+ ", " + df["Property_City"].str.strip() + " " + df["Property_Zip_Code"].astype(str))
#df["full_address"] = (df["Clean_Address"].str.strip()+ ", " + df["Property_City"].str.strip())
df["full_address"].head()
# Out:
# 0     412 Sw 7th Ct, Boynton Beach 33435
# 1     805 Sw 3rd St, Boynton Beach 33435
# 2     801 Sw 2nd St, Boynton Beach 33435
# 3     720 Sw 2nd St, Boynton Beach 33435
# 4    223 Sw 7th Ave, Boynton Beach 33435
# Name: full_address, dtype: object

# %%
#helper function to check for empty addresses

def is_empty_address(address):
    if address is None:
        return True
    if isinstance(address, float):  # NaN case
        return True
    if address.strip() == "":
        return True
    return False

# %%
#api call payload builder needs address to look for in the searchText field

def build_payload(search_address):
    return {
        "inputName": "addresssearch",
        "searchLimit": "20",
        "uID": "89540f28-8b9a-4aed-b609-72529f86a3ca",
        "version": 2,
        "removeZip": True,
        "papaVersion": True,
        "removeChar": "_",
        "removeSpace": True,
        "papaVariance": False,
        "searchText": search_address
        }

# %%
#calling api and returning json response
def api_call(address):
    url = "https://maps.pbc.gov/giswebapi/anysearch"
    response = requests.post(url, json=build_payload(address))
    if response.status_code == 200:
        data = response.json()
        return data
    else:
        print(f"Error: {response.status_code}")
        return None

# %%
#helper function to normalize text : convert everything in to upercase and remove extra spaces and adds only 1 space between words
def normalize(text):
    return " ".join(text.upper().split())

# %%
#finds the pcn number from the api response data for the given address
def get_pcn_number(address, data):
    address_norm = normalize(address)
    for item in data:
         search_term = item.get("searchTerm", "")
         if normalize(search_term) == address_norm:
            print("get_pcn_number :" + str(item.get("PCN")))
            return item.get("PCN")

    return None

# %%
# calling api and getting pcn number for the given address
def get_pcn(address):
    if is_empty_address(address):
        return None
    
    data = api_call(address)
    if not data:
        return None

    return get_pcn_number(address, data)

# %%
#saving all the pcn results in a list
pcn_results = []

for idx, row in df.iterrows():
    address = row["full_address"]
    print(f"Processing row {idx}: {address}")
    pcn = get_pcn(address)
    pcn_results.append(pcn)
# Out:
# Processing row 0: 412 Sw 7th Ct, Boynton Beach 33435
# get_pcn_number :08434528190000211
# Processing row 1: 805 Sw 3rd St, Boynton Beach 33435
# Processing row 2: 801 Sw 2nd St, Boynton Beach 33435
# get_pcn_number :08434528220090010
# Processing row 3: 720 Sw 2nd St, Boynton Beach 33435
# get_pcn_number :08434528220010250
# Processing row 4: 223 Sw 7th Ave, Boynton Beach 33435
# get_pcn_number :08434528220010361
# Processing row 5: 219 Sw 7th Ave, Boynton Beach 33435
# get_pcn_number :08434528220010381
# Processing row 6: 904 S Seacrest Blvd, Boynton Beach 33435
# get_pcn_number :08434528120200110
# Processing row 7: 118 Sw 8th Ave, Boynton Beach 33435
# get_pcn_number :08434528120210041
# Processing row 8: 127 Sw 8th Ave, Boynton Beach 33435
# get_pcn_number :08434528120160170
# Processing row 9: 145 Sw 8th Ave, Boynton Beach 33435
# get_pcn_number :08434528120160130
# Processing row 10: 139 Sw 8th Ave, Boynton Beach 33435
# get_pcn_number :08434528120160150
# Processing row 11: 423 Sw 9th Ave, Boynton Beach 33435
# get_pcn_number :08434528160100061
# Processing row 12: 402 Sw 9th Ave, Boynton Beach 33435
# get_pcn_number :08434528160090231
# Processing row 13: 301 Sw 9th Ave, Boynton Beach 33435
# get_pcn_number :08434528220080450
# Processing row 14: 117 Sw 9th Ave, Boynton Beach 33435
# get_pcn_number :08434528120210210
# Processing row 15: 145 Sw 10th Ave, Boynton Beach 33435
# get_pcn_number :08434528120220130
# Processing row 16: 130 Sw 13th Ave, Boynton Beach 33435
# get_pcn_number :08434528130090080
# Processing row 17: 393 399 W Woolbright Rd, Boynton Beach 33435
# Processing row 18: 1445 1479 Sw 3rd St, Boynton Beach 33435
# Processing row 19: 448 Sw 10th Ave, Boynton Beach 33435
# get_pcn_number :08434528160080111
# Processing row 20: 1002 Sw 4th St, Boynton Beach 33435
# get_pcn_number :08434528160090130
# Processing row 21: 205 Sw 4th St, Boynton Beach 33435
# get_pcn_number :08434528140620151
# Processing row 22: 115 Sw 4th St, Boynton Beach 33435
# get_pcn_number :08434528140630190
# Processing row 23: 315 Nw 3rd St, Boynton Beach 33435
# get_pcn_number :08434521160001260
# Processing row 24: 211 Nw 7th Ct, Boynton Beach 33435
# get_pcn_number :08434521070031690
# Processing row 25: 224 Nw 7th Ct, Boynton Beach 33435
# get_pcn_number :08434521070031711
# Processing row 26: 213 Nw 7th Ct, Boynton Beach 33435
# get_pcn_number :08434521070031690
# Processing row 27: 215 Nw 7th Ct, Boynton Beach 33435
# get_pcn_number :08434521070031680
# Processing row 28: 110 Nw 5th Ct, Boynton Beach 33435
# get_pcn_number :08434521070021360
# Processing row 29: 112 Nw 5th Ave, Boynton Beach 33435
# get_pcn_number :08434521070021430
# Processing row 30: 115 Nw 6th Ave, Boynton Beach 33435
# get_pcn_number :08434521070031020
# Processing row 31: 125 Nw 6th Ave, Boynton Beach 33435
# get_pcn_number :08434521070031040
# Processing row 32: 1016 Nw 4th St, Boynton Beach 33435
# Processing row 33: 1030 Nw 4th St, Boynton Beach 33435
# get_pcn_number :08434521140002340
# Processing row 34: 415 Nw 12th Ave, Boynton Beach 33435
# get_pcn_number :08434521140004220
# Processing row 35: 548 Nw 13th Ave, Boynton Beach 33435
# Processing row 36: 521 Nw 13th Ave, Boynton Beach 33435
# get_pcn_number :08434521330000030
# Processing row 37: 430 Nw 6th Ave, Boynton Beach 33435
# get_pcn_number :08434521160000750
# Processing row 38: 220 Nw 6th Ave, Boynton Beach 33435
# get_pcn_number :08434521070021120
# Processing row 39: 221 Nw 5th Ct, Boynton Beach 33435
# get_pcn_number :08434521070021160
# Processing row 40: 610 Nw 2nd St, Boynton Beach 33435
# get_pcn_number :08434521070021770
# Processing row 41: 509 Nw 2nd St, Boynton Beach 33435
# get_pcn_number :08434521070021871
# Processing row 42: 132 Nw 4th Ave, Boynton Beach 33435
# get_pcn_number :08434521070011540
# Processing row 43: 120 Nw 4th Ave, Boynton Beach 33435
# get_pcn_number :08434521070011500
# Processing row 44: 112 Nw 4th Ave, Boynton Beach 33435
# get_pcn_number :08434521070011480
# Processing row 45: 119 Nw 3rd Ave, Boynton Beach 33435
# get_pcn_number :08434521070011420
# Processing row 46: 301 311 Nw 2nd St, Boynton Beach 33435
# Processing row 47: 320 Nw 2nd St, Boynton Beach 33435
# get_pcn_number :08434521070011760
# Processing row 48: 356 Nw 2nd St, Boynton Beach 33435
# Processing row 49: 404 Nw 8th Ave, Boynton Beach 33435
# get_pcn_number :08434521160000490
# Processing row 50: 304 Nw 8th Ave, Boynton Beach 33435
# get_pcn_number :08434521070031881
# Processing row 51: 921 Nw 3rd St, Boynton Beach 33435
# get_pcn_number :08434521140000960
# Processing row 52: 1004 Nw 3rd St, Boynton Beach 33435
# get_pcn_number :08434521140001100
# Processing row 53: 424 Nw 9th Ave, Boynton Beach 33435
# get_pcn_number :08434521140000870
# Processing row 54: 513 Nw 9th Ave, Boynton Beach 33435
# get_pcn_number :08434521140001441
# Processing row 55: 503 Nw 9th Ave, Boynton Beach 33435
# get_pcn_number :08434521140001400
# Processing row 56: 533 Nw Martin Luther King Jr Blvd, Boynton Beach 33435
# Processing row 57: 530 Nw Martin Luther King Jr Blvd, Boynton Beach 33435
# Processing row 58: 519 Nw Martin Luther King Jr Blvd, Boynton Beach 33435
# Processing row 59: 501 599 Nw Martin Luther King Jr Blvd, Boynton Beach 33435
# Processing row 60: 1032 Nw 4th St, Boynton Beach 33435
# get_pcn_number :08434521140002340
# Processing row 61: 222 Nw 11th Ave, Boynton Beach 33435
# get_pcn_number :08434521170010140
# Processing row 62: 426 Nw 11th Ave, Boynton Beach 33435
# get_pcn_number :08434521140003040
# Processing row 63: 433 Nw 11th Ave, Boynton Beach 33435
# Processing row 64: 538 Nw 11th Ave, Boynton Beach 33435
# get_pcn_number :08434521140002810
# Processing row 65: 1203 Nw 4th St, Boynton Beach 33435
# get_pcn_number :08434521140003360
# Processing row 66: 509 Nw 12th Ave, Boynton Beach 33435
# get_pcn_number :08434521140004360
# Processing row 67: 539 Nw 8th Ave, Boynton Beach 33435
# get_pcn_number :08434521140000440
# Processing row 68: 636 Nw 5th St, Boynton Beach 33435
# get_pcn_number :08434521130000150

# %%
#creating a new column in dataframe to save pcn results
df["PCN"] = pcn_results
df["PCN"].head()
# Out:
# 0    08434528190000211
# 1                 None
# 2    08434528220090010
# 3    08434528220010250
# 4    08434528220010361
# Name: PCN, dtype: object

# %%
# function to get property details using pcn number
def get_property_details(pcn):
    if pcn is None or str(pcn).strip() == "":
        return None
    
    url = "https://pbcpao.gov/Property/MapDetails"
    params ={"parcelId": pcn}
    
    response = requests.get(url, params=params)
    if response.status_code == 200:
        return response.text
    else:
        print(f"Error fetching details for PCN {pcn}: {response.status_code}")
        return None

# %%
#getting owners from the property details page
def get_owners(soup):
    owners_section = soup.find("div", class_="map-owners")
    if not owners_section:
        return None

    owners = [
        td.get_text(" ", strip=True)
        for td in owners_section.find_all("td")
        if td.get_text(strip=True)
    ]

    return "; ".join(owners) if owners else None

# %%
#getting mailing address from the property details page
def get_mailing_address(soup):
    for row in soup.find_all("tr"):
        label_cell = row.find("td", class_="label")
        if not label_cell:
            continue

        if label_cell.get_text(strip=True) == "Mailing Address":
            value_cell = row.find("td", class_="value")
            if not value_cell:
                return None

            lines = [
                label.get_text(strip=True)
                for label in value_cell.find_all("label")
                if label.get_text(strip=True)
            ]

            return ", ".join(lines) if lines else None

    return None

# %%
#saving the parsed property details in a dictionary
def parse_property_html(html):
    soup = BeautifulSoup(html, "html.parser")

    return {
        "Owner_Name": get_owners(soup),
        "Mailing_Address": get_mailing_address(soup)
    }

# %%
#creating new columns for Owner_Name and Mailing_Address
df["Owner_Name"] = None
df["Mailing_Address"] = None

for idx, pcn in df["PCN"].items():
    if pd.isna(pcn) or not str(pcn).strip():
        print(f"Skipping row {idx} due to missing PCN")
        continue
    
    try:
        html= get_property_details(pcn)
        parsed = parse_property_html(html)
        df.at[idx, "Owner_Name"] = parsed.get("Owner_Name")
        df.at[idx, "Mailing_Address"] = parsed.get("Mailing_Address")
        print(f"Processed PCN {pcn}")
        
    except Exception as e:
        print(f"Failed PCN {pcn}: {e}")

# %%
df.to_csv("data/property_address_with_owner_and_mailing.csv", index=False)
